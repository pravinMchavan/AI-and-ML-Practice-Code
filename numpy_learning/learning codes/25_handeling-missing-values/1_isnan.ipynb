# %% [markdown]
# #np.isnan
# it means not a number
# it use to find missing values

# %%
import numpy as np
arr = np.array([1,2, np.nan, 4,np.nan,6])
print(np.isnan(arr))
# Out:
# [False False  True False  True False]
